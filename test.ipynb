# %%
def print_reverse(str):
    print(str[::-1])

print_reverse("python")
# Out:
# nohtyp

# %%
def print_score(list):
    print(sum(list)/len(list))

print_score ([1, 2, 3])
# Out:
# 2.0

# %%
def print_even(list):
    for i in list:
        if i%2==0:
            print(i)

print_even ([1, 3, 2, 10, 12, 11, 15])
# Out:
# 2
# 10
# 12

# %%
def print_keys(dic):
    print(dic.keys())
       
print_keys ({"이름":"김말똥", "나이":30, "성별":0})
# Out:
# dict_keys(['이름', '나이', '성별'])

# %%
my_dict = {"10/26" : [100, 130, 100, 100],
           "10/27" : [10, 12, 10, 11]}

def print_value_by_key(dict, date):
    print(dict[date])

print_value_by_key  (my_dict, "10/26")
# Out:
# [100, 130, 100, 100]

# %%
def print_5xn(string):
    for i in range((len(string)/5)):
        print(string[i*5:i*5+5])

print_5xn("아이엠어보이유알어걸")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\PARKMI~1\AppData\Local\Temp/ipykernel_28684/1044267446.py in <module>
#       3         print(string[i*5:i*5+5])
#       4
# ----> 5 print_5xn("아이엠어보이유알어걸")
#
# C:\Users\PARKMI~1\AppData\Local\Temp/ipykernel_28684/1044267446.py in print_5xn(string)
#       1 def print_5xn(string):
# ----> 2     for i in range((len(string)/5)):
#       3         print(string[i*5:i*5+5])
#       4
#       5 print_5xn("아이엠어보이유알어걸")
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
def print_mxn(string, num):
    chunk = int(len(string)/num) #10글자면 -> 3 
    for i in chunk:
        print(string[num*i:num*i+num])


print_mxn("아이엠어보이유알어걸", 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\PARKMI~1\AppData\Local\Temp/ipykernel_28684/3659333808.py in <module>
#       5
#       6
# ----> 7 print_mxn("아이엠어보이유알어걸", 3)
#
# C:\Users\PARKMI~1\AppData\Local\Temp/ipykernel_28684/3659333808.py in print_mxn(string, num)
#       1 def print_mxn(string, num):
#       2     chunk = int(len(string)/num) #10글자면 -> 3
# ----> 3     for i in chunk:
#       4         print(string[num*i:num*i+num])
#       5
#
# TypeError: 'int' object is not iterable

# %%
def print_mxn(string, num):
    chunk = int(len(string)/num)
    for i in range(chunk+1):
        print(string[num*i:num*i+num])

print_mxn("아이엠어보이유알어걸", 3)
# Out:
# 아이엠
# 어보이
# 유알어
# 걸

# %%
def calc_monthly_salary(annual_salary):
    return(int(annual_salary/12))

calc_monthly_salary(12000000)
# Out:
# 1000000

# %%
def make_url(address):
    url = "www." +  address +  ".com"
    return url

make_url("naver")
# Out:
# 'www.naver.com'

# %%
def make_list(str):
    return(list(str))

make_list("abcd")
# Out:
# ['a', 'b', 'c', 'd']

# %%
def make_list(str):
    list = []
    for i in str:
        list.append(i)
    return(list)

make_list("abcd")
# Out:
# ['a', 'b', 'c', 'd']

# %%
def pickup_even(list):
    new_list = []
    for i in list:
        if i%2 == 0:
            new_list.append(i)
    return new_list

pickup_even([3, 4, 5, 6, 7, 8])
# Out:
# [4, 6, 8]

# %%
def convert_int(str_number):
    str_number = str_number.replace(",","")
    return(int(str_number))

convert_int("1,234,567")
# Out:
# 1234567

# %%
import datetime

now = datetime.datetime.now()
print(now)
# Out:
# 2021-08-16 22:31:46.552040

# %%
now = datetime.datetime.now()
print(type(now))
# Out:
# <class 'datetime.datetime'>

# %%
now = datetime.datetime.now()

for day in range(5, 0, -1):
    delta = datetime.timedelta(days=day)
    result = now - delta
    print(result)
# Out:
# 2021-08-11 22:46:23.162007
# 2021-08-12 22:46:23.162007
# 2021-08-13 22:46:23.162007
# 2021-08-14 22:46:23.162007
# 2021-08-15 22:46:23.162007

# %%
what = datetime.timedelta()
print(what)
# Out:
# 0:00:00

# %%
import datetime

now = datetime.datetime.now()

for day in range(5,0,-1):
    delta = datetime.timedelta(days=day)
    result = now - delta
    print(result)
# Out:
# 2021-08-11 22:50:34.730552
# 2021-08-12 22:50:34.730552
# 2021-08-13 22:50:34.730552
# 2021-08-14 22:50:34.730552
# 2021-08-15 22:50:34.730552

# %%
now = datetime.datetime.now()

print(now.strftime)
# Out:
# <built-in method strftime of datetime.datetime object at 0x000001D1AA8E7270>

# %%
print(datetime.datetime.strptime("2020-05-04"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\PARKMI~1\AppData\Local\Temp/ipykernel_28684/1440891590.py in <module>
# ----> 1 print(datetime.datetime.strptime("2020-05-04"))
#
# TypeError: strptime() takes exactly 2 arguments (1 given)

# %%
day = "2020-05-04"
result = datetime.datetime.strptime(day, "%Y-%m-%d")
print(result, type(result))
# Out:
# 2020-05-04 00:00:00 <class 'datetime.datetime'>

# %%
now = datetime.datetime.now()
print(now.strftime("%H:%M:%S"))
# Out:
# 22:52:23

# %%
import os

result = os.getcwd()
print(result, type(result))
# Out:
# c:\Users\Parkminjeong\Documents\GitHub\Algorithm <class 'str'>

# %%
import numpy

for i in numpy.arange(0, 5, 0.1):
    print(i)
# Out:
# 0.0
# 0.1
# 0.2
# 0.30000000000000004
# 0.4
# 0.5
# 0.6000000000000001
# 0.7000000000000001
# 0.8
# 0.9
# 1.0
# 1.1
# 1.2000000000000002
# 1.3
# 1.4000000000000001
# 1.5
# 1.6
# 1.7000000000000002
# 1.8
# 1.9000000000000001
# 2.0
# 2.1
# 2.2
# 2.3000000000000003
# 2.4000000000000004
# 2.5
# 2.6
# 2.7
# 2.8000000000000003
# 2.9000000000000004
# 3.0
# 3.1
# 3.2
# 3.3000000000000003
# 3.4000000000000004
# 3.5
# 3.6
# 3.7
# 3.8000000000000003
# 3.9000000000000004
# 4.0
# 4.1000000000000005
# 4.2
# 4.3
# 4.4
# 4.5
# 4.6000000000000005
# 4.7
# 4.800000000000001
# 4.9

# %%
class Human:
    pass

# %%
class Human:
    print("응애응애")

Human()
# Out:
# 응애응애

# %%
class Human:
    def __init__ (self, name, age, gender):
        self.name = name
        self.age = age
        self.gender = gender

areum = Human("아름", 25, "여자")
print(areum.name)
# Out:
# 아름

# %%
areum = Human("조아름", 25, "여자")
print(areum.name)
print(areum.age)
print(areum.gender)
# Out:
# 조아름
# 25
# 여자
